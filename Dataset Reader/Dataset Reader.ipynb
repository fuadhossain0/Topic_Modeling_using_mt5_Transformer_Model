# %%
import json

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = "/content/drive/MyDrive/Thesis Final/Working Files/Dataset/"

news_file1 = path + "Dataset_1.json"
news_file2 = path + "Dataset_2.json"
news_file3 = path + "Dataset_3.json"
news_file4 = path + "Dataset_4.json"
news_file5 = path + "Dataset_5.json"

# %%
news_list1 = []
news_list2 = []
news_list3 = []
news_list4 = []
news_list5 = []

with open(news_file1, "r", encoding="utf-8") as fp1:
  news_list1 = json.load(fp1)

with open(news_file2, "r", encoding="utf-8") as fp2:
  news_list2 = json.load(fp2)

with open(news_file3, "r", encoding="utf-8") as fp3:
  news_list3 = json.load(fp3)

with open(news_file4, "r", encoding="utf-8") as fp4:
  news_list4 = json.load(fp4)

with open(news_file5, "r", encoding="utf-8") as fp5:
  news_list5 = json.load(fp5)

# %%
news_list1

# %%
news_list2

# %%
news_list3

# %%
news_list4

# %%
news_list5
